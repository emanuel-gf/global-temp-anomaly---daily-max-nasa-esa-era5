# %%
import pandas as pd
import numpy as np
import os 
import datetime

# %% [markdown]
# ## Explain
# This notebook is joining all the csv files from the openmeteo requests into a singular one to processing.
#
# It is part of the processing chain to Predict GLobal anomaly monthly temperature.
#
# This preprocessing part joing the different csv and also process that dataset to be a Tensor structure ready for further NN models.

# %%
datapath = "/home/camarada/Documents/projects/temp-grss-nasa/data_/ecmwf_temp_openmeteo"
df = pd.read_csv(os.path.join(datapath, 'ecmwf_weather_batch_0_60.csv'))

## convert to date
df['date'] = pd.to_datetime(df['date'])

## create a day-month-year column
df['dmy'] = df['date'].dt.date

print(df.shape)
## filter a wrong value
df = df.loc[(df['dmy']>=datetime.date(2023, 1, 1))&(df['dmy']<datetime.date(2026, 1, 1))]

print(df.shape)
# Out:
# (67620, 6)
# (65760, 6)

# %%
df.tail()
# Out:
#                            date       capital  avg_temp_c   latitude  \
# 67585 2025-12-27 21:00:00+00:00  Antananarivo   20.564580 -18.945518
# 67586 2025-12-28 21:00:00+00:00  Antananarivo   20.050001 -18.945518
# 67587 2025-12-29 21:00:00+00:00  Antananarivo   21.506250 -18.945518
# 67588 2025-12-30 21:00:00+00:00  Antananarivo   20.497920 -18.945518
# 67589 2025-12-31 21:00:00+00:00  Antananarivo   19.462500 -18.945518
#
#        longitude         dmy
# 67585  47.527092  2025-12-27
# 67586  47.527092  2025-12-28
# 67587  47.527092  2025-12-29
# 67588  47.527092  2025-12-30
# 67589  47.527092  2025-12-31

# %%
df2 = pd.read_csv(os.path.join(datapath,'ecmwf_weather_batch_60_117.csv'))

df2['date'] = pd.to_datetime(df2['date'])

## create a day-month-year column
df2['dmy'] = df2['date'].dt.date

print(df2.shape)
## filter a wrong value
df2 = df2.loc[(df2['dmy']>=datetime.date(2023, 1, 1))&(df2['dmy']<datetime.date(2026, 1, 1))]


print(df2.shape)
# Out:
# (64239, 6)
# (62472, 6)

# %%
df2.tail()
# Out:
#                            date   capital  avg_temp_c   latitude  longitude  \
# 64203 2025-12-27 04:00:00+00:00  San Juan   24.266663  18.453426  -66.13504
# 64204 2025-12-28 04:00:00+00:00  San Juan   23.610415  18.453426  -66.13504
# 64205 2025-12-29 04:00:00+00:00  San Juan   23.502080  18.453426  -66.13504
# 64206 2025-12-30 04:00:00+00:00  San Juan   24.635416  18.453426  -66.13504
# 64207 2025-12-31 04:00:00+00:00  San Juan   25.308334  18.453426  -66.13504
#
#               dmy
# 64203  2025-12-27
# 64204  2025-12-28
# 64205  2025-12-29
# 64206  2025-12-30
# 64207  2025-12-31

# %%
df3 = pd.read_csv(os.path.join(datapath,'ecmwf_weather_batch_0_117_2020-01-01_2022-12-31.csv'))
df3['date'] = pd.to_datetime(df3['date'])

## create a day-month-year column
df3['dmy'] = df3['date'].dt.date

print(df3.shape)
## filter a wrong value
df3 = df3.loc[df3['dmy']>=datetime.date(2020, 1, 1)]

print(df3.shape)
# Out:
# (128232, 6)
# (128143, 6)

# %%
df3.tail()
# Out:
#                             date   capital  avg_temp_c   latitude  longitude  \
# 128227 2022-12-27 04:00:00+00:00  San Juan   25.983332  18.453426  -66.13504
# 128228 2022-12-28 04:00:00+00:00  San Juan   25.268751  18.453426  -66.13504
# 128229 2022-12-29 04:00:00+00:00  San Juan   25.510414  18.453426  -66.13504
# 128230 2022-12-30 04:00:00+00:00  San Juan   25.472918  18.453426  -66.13504
# 128231 2022-12-31 04:00:00+00:00  San Juan   25.760416  18.453426  -66.13504
#
#                dmy
# 128227  2022-12-27
# 128228  2022-12-28
# 128229  2022-12-29
# 128230  2022-12-30
# 128231  2022-12-31

# %%
df4 = pd.read_csv(os.path.join(datapath,'ecmwf_weather_batch_0_117_2017-01-01_2019-12-31.csv'))
df4['date'] = pd.to_datetime(df4['date'])

## create a day-month-year column
df4['dmy'] = df4['date'].dt.date

print(df4.shape)
## filter a wrong value
df4 = df4.loc[df4['dmy']>=datetime.date(2017, 1, 1)]

print(df4.shape)
# Out:
# (128115, 6)
# (128026, 6)

# %%
df4.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df4.tail()
#
# NameError: name 'df4' is not defined

# %%
df5 =  pd.read_csv(os.path.join(datapath,'ecmwf_weather_batch_0_117_2026-01-01_2026-02-28.csv'))
df5['date'] = pd.to_datetime(df5['date'])

## create a day-month-year column
df5['dmy'] = df5['date'].dt.date

print(df5.shape)
## filter a wrong value
df5 = df5.loc[df5['dmy']>=datetime.date(2026, 1, 1)]

print(df5.shape)
# Out:
# (6903, 6)
# (6815, 6)

# %%
df5.head()
# Out:
#                        date           capital  avg_temp_c   latitude  \
# 1 2026-01-01 23:00:00+00:00  Andorra la Vella    3.825167  42.425304
# 2 2026-01-02 23:00:00+00:00  Andorra la Vella    4.791833  42.425304
# 3 2026-01-03 23:00:00+00:00  Andorra la Vella    3.054333  42.425304
# 4 2026-01-04 23:00:00+00:00  Andorra la Vella   -0.426917  42.425304
# 5 2026-01-05 23:00:00+00:00  Andorra la Vella   -3.237333  42.425304
#
#    longitude         dmy
# 1   1.453745  2026-01-01
# 2   1.453745  2026-01-02
# 3   1.453745  2026-01-03
# 4   1.453745  2026-01-04
# 5   1.453745  2026-01-05

# %%
df5.sort_values(by=['dmy','capital'])
# Out:
#                           date           capital  avg_temp_c   latitude  \
# 6609 2026-01-01 20:00:00+00:00         Abu Dhabi   19.833334  24.428822
# 3954 2026-01-01 23:00:00+00:00             Abuja   29.908333   9.033392
# 1889 2026-01-01 21:00:00+00:00       Addis Ababa   13.712499   9.033392
# 5783 2026-01-01 23:00:00+00:00           Algiers   12.021500  36.731106
# 2951 2026-01-01 21:00:00+00:00             Amman    7.678584  31.950790
# ...                        ...               ...         ...        ...
# 6017 2026-02-28 06:00:00+00:00      San Salvador   25.781000  13.673111
# 1120 2026-02-28 03:00:00+00:00          Santiago   22.679167 -33.427067
# 1710 2026-02-28 04:00:00+00:00     Santo Domingo   24.418833  18.523726
# 707  2026-02-28 04:00:00+00:00             Sucre   14.447331 -19.086117
# 5545 2026-02-28 05:00:00+00:00  Washington, D.C.    7.533333  38.910366
#
#       longitude         dmy
# 6609  54.364998  2026-01-01
# 3954   7.474049  2026-01-01
# 1889  38.771626  2026-01-01
# 5783   3.070866  2026-01-01
# 2951  35.891567  2026-01-01
# ...         ...         ...
# 6017 -89.174316  2026-02-28
# 1120 -70.642761  2026-02-28
# 1710 -69.902039  2026-02-28
# 707  -65.212250  2026-02-28
# 5545 -77.072510  2026-02-28
#
# [6815 rows x 6 columns]

# %%
## concat boths
concat = pd.concat([df, df2, df3, df4, df5], axis=0)

## create a new column YEAR-MONTH
concat['month_year']=pd.to_datetime(concat['date']).dt.strftime("%Y-%m")

## convert all capitals to lower
concat['capital'] = concat['capital'].apply(lambda x:x.lower())

## sort by capital and by date
concat = concat.sort_values(by=['dmy','capital'])

# %%
concat['capital'].unique().shape
# Out:
# (117,)

# %%
concat.tail()
# Out:
#                           date           capital  avg_temp_c   latitude  \
# 6017 2026-02-28 06:00:00+00:00      san salvador   25.781000  13.673111
# 1120 2026-02-28 03:00:00+00:00          santiago   22.679167 -33.427067
# 1710 2026-02-28 04:00:00+00:00     santo domingo   24.418833  18.523726
# 707  2026-02-28 04:00:00+00:00             sucre   14.447331 -19.086117
# 5545 2026-02-28 05:00:00+00:00  washington, d.c.    7.533333  38.910366
#
#       longitude         dmy month_year
# 6017 -89.174316  2026-02-28    2026-02
# 1120 -70.642761  2026-02-28    2026-02
# 1710 -69.902039  2026-02-28    2026-02
# 707  -65.212250  2026-02-28    2026-02
# 5545 -77.072510  2026-02-28    2026-02

# %%
for capital in concat['capital'].unique():
    print(capital)
# Out:
# abu dhabi
# abuja
# addis ababa
# algiers
# amman
# amsterdam
# andorra la vella
# ankara
# antananarivo
# ashgabat
# astana
# athens
# bangkok
# beijing
# beirut
# belgrade
# berlin
# bern
# bishkek
# bogota
# bordeaux
# brasilia
# bratislava
# brazzaville
# brussels
# bucharest
# budapest
# buenos aires
# cairo
# calafate
# canberra
# caracas
# copenhagen
# dakar
# doha
# dublin
# florianopolis
# gold coast
# guatemala city
# hanoi
# harare
# havana
# helsinki
# hong kong
# jakarta
# jerusalem
# kathmandu
# kiev
# kingston
# kinshasa
# kuala lumpur
# lima
# lisbon
# ljubljana
# london
# luanda
# luxembourg city
# madrid
# managua
# manila
# maputo
# milan
# minsk
# monaco
# montevideo
# moscow
# munich
# nairobi
# napoli
# nicosia
# oslo
# ottawa
# panama city
# paris
# podgorica
# port louis
# port of spain
# prague
# pretoria
# quito
# rabat
# rennes
# reykjavik
# salzburg
# san jose
# san juan
# san salvador
# santiago
# santo domingo
# sarajevo
# seoul
# singapore
# skopje
# sofia
# sri jayewardenepura kotte
# stockholm
# sucre
# suva
# taipei
# tallinn
# tbilisi
# tehran
# tirana
# tokyo
# tripoli
# tunis
# ulaanbaatar
# valletta
# vientiane
# vilnius
# warsaw
# washington, d.c.
# wellington
# windhoek
# yakutsk
# yerevan
# zagreb

# %% [markdown]
# ## True Anomaly
#
# Nasa dataset

# %%
df_nasa = pd.read_csv('data_/nasa/1981-2025.csv')

# %%
df_long = df_nasa.melt(id_vars=['Year'], var_name='Month', value_name='Value')

df_long['Date'] = pd.to_datetime(df_long['Year'].astype(str) + df_long['Month'], format='%Y%b')

# 3. Clean up: Sort by date and set it as the index
df_ts = df_long.sort_values('Date').set_index('Date').drop(columns=['Year', 'Month'])

df_ts.reset_index(inplace=True)

## create a new column YEAR-MONTH
df_ts['month_year']=pd.to_datetime(df_ts['Date']).dt.strftime("%Y-%m")

## apply scaler to celsius
df_ts['Value'] = df_ts['Value']/ 100
df_ts.head()
# Out:
#         Date  Value month_year
# 0 1981-01-01   0.53    1981-01
# 1 1981-02-01   0.42    1981-02
# 2 1981-03-01   0.48    1981-03
# 3 1981-04-01   0.32    1981-04
# 4 1981-05-01   0.24    1981-05

# %% [markdown]
# ## Create dataset structure
#
# This is a ready structure to be passed into a tensor

# %%
## filter the concat before the 2026-01-01 since there is no true data for this period
concat2325 = concat.loc[concat['dmy']<datetime.date(2026,1,1)]
concat26 = concat.loc[concat['dmy']>=datetime.date(2026,1,1)]

# %%
### Create arrays and save as npz

## root_dir =
root_dir = os.getcwd()
n_capitals = 117  # number of capitals
n_timepoints = 31  # days

uniq_capital = concat2325['capital'].unique()
month_years = concat2325['month_year'].unique()
n_samples = len(month_years)

## IMPORTANT
## sort by capital name
concat2325 = concat2325.sort_values(by=['dmy','capital']).copy()

# Pre-allocate arrays
temp_matrices = np.zeros((n_samples, n_capitals, n_timepoints), dtype=np.float32)
masks = np.zeros((n_samples, n_capitals, n_timepoints), dtype=np.float32)
labels = np.zeros(n_samples, dtype=np.float32)
month_year_list = []

for idx, my in enumerate(month_years):
    print(f"Processing: {my}")

    try:
        # Get data for this month/year
        month_data = concat2325[concat2325['month_year'] == my]

        for i, capital in enumerate(uniq_capital):
            capital_data = month_data[month_data['capital'] == capital].sort_values('dmy')
            temp_values = capital_data['avg_temp_c'].values

            if len(temp_values) > 0:
                temp_matrices[idx, i, :len(temp_values)] = temp_values
                masks[idx, i, :len(temp_values)] = 1.0

        # Get the true anomaly
        anomaly_value = df_ts[df_ts['month_year'] == my]['Value'].values[0]
        labels[idx] = anomaly_value
        month_year_list.append(my)
    except Exception as e:
        print(f"Couldnt process: {my}")
# Out:
# Processing: 2017-01
# Processing: 2017-02
# Processing: 2017-03
# Processing: 2017-04
# Processing: 2017-05
# Processing: 2017-06
# Processing: 2017-07
# Processing: 2017-08
# Processing: 2017-09
# Processing: 2017-10
# Processing: 2017-11
# Processing: 2017-12
# Processing: 2018-01
# Processing: 2018-02
# Processing: 2018-03
# Processing: 2018-04
# Processing: 2018-05
# Processing: 2018-06
# Processing: 2018-07
# Processing: 2018-08
# Processing: 2018-09
# Processing: 2018-10
# Processing: 2018-11
# Processing: 2018-12
# Processing: 2019-01
# Processing: 2019-02
# Processing: 2019-03
# Processing: 2019-04
# Processing: 2019-05
# Processing: 2019-06
# Processing: 2019-07
# Processing: 2019-08
# Processing: 2019-09
# Processing: 2019-10
# Processing: 2019-11
# Processing: 2019-12
# Processing: 2020-01
# Processing: 2020-02
# Processing: 2020-03
# Processing: 2020-04
# Processing: 2020-05
# Processing: 2020-06
# Processing: 2020-07
# Processing: 2020-08
# Processing: 2020-09
# Processing: 2020-10
# Processing: 2020-11
# Processing: 2020-12
# Processing: 2021-01
# Processing: 2021-02
# Processing: 2021-03
# Processing: 2021-04
# Processing: 2021-05
# Processing: 2021-06
# Processing: 2021-07
# Processing: 2021-08
# Processing: 2021-09
# Processing: 2021-10
# Processing: 2021-11
# Processing: 2021-12
# Processing: 2022-01
# Processing: 2022-02
# Processing: 2022-03
# Processing: 2022-04
# Processing: 2022-05
# Processing: 2022-06
# Processing: 2022-07
# Processing: 2022-08
# Processing: 2022-09
# Processing: 2022-10
# Processing: 2022-11
# Processing: 2022-12
# Processing: 2023-01
# Processing: 2023-02
# Processing: 2023-03
# Processing: 2023-04
# Processing: 2023-05
# Processing: 2023-06
# Processing: 2023-07
# Processing: 2023-08
# Processing: 2023-09
# Processing: 2023-10
# Processing: 2023-11
# Processing: 2023-12
# Processing: 2024-01
# Processing: 2024-02
# Processing: 2024-03
# Processing: 2024-04
# Processing: 2024-05
# Processing: 2024-06
# Processing: 2024-07
# Processing: 2024-08
# Processing: 2024-09
# Processing: 2024-10
# Processing: 2024-11
# Processing: 2024-12
# Processing: 2025-01
# Processing: 2025-02
# Processing: 2025-03
# Processing: 2025-04
# Processing: 2025-05
# Processing: 2025-06
# Processing: 2025-07
# Processing: 2025-08
# Processing: 2025-09
# Processing: 2025-10
# Processing: 2025-11
# Processing: 2025-12

# %%
## save 
# Save to npz file

## the files are organized by ascendend order given by capital name
np.savez_compressed(
    'data_/openmeteo-1725-temp.npz',
    temp_matrices=temp_matrices,  # shape: (n_samples, n_capitals, n_timepoints)
    masks=masks,                  # shape: (n_samples, n_capitals, n_timepoints)
    labels=labels,                # shape: (n_samples,)
    month_years=np.array(month_year_list),  # shape: (n_samples,)
    capitals=uniq_capital         # shape: (n_capitals,)
)

# %%
masks.shape
# Out:
# (38, 117, 31)

# %%
labels.shape
# Out:
# (38,)

# %%
labels[-1]
# Out:
# np.float32(0.0)

# %%
month_year_list[-1]
# Out:
# '2025-12'

# %%
anomaly_value
# Out:
# np.float64(1.05)

# %% [markdown]
# ## Values to be infered

# %%
concat26.head()
# Out:
#                            date      capital  avg_temp_c   latitude  \
# 59701 2026-01-01 20:00:00+00:00    abu dhabi   19.833334  24.428822
# 6609  2026-01-01 20:00:00+00:00    abu dhabi   19.833334  24.428822
# 8986  2026-01-01 23:00:00+00:00        abuja   29.908333   9.033392
# 3954  2026-01-01 23:00:00+00:00        abuja   29.908333   9.033392
# 1889  2026-01-01 21:00:00+00:00  addis ababa   13.712499   9.033392
#
#        longitude         dmy month_year
# 59701  54.364998  2026-01-01    2026-01
# 6609   54.364998  2026-01-01    2026-01
# 8986    7.474049  2026-01-01    2026-01
# 3954    7.474049  2026-01-01    2026-01
# 1889   38.771626  2026-01-01    2026-01

# %%
### Create arrays and save as npz

## THere is no labels to save here! 
## Since it is the month to predict the anomaly

## root_dir =
root_dir = os.getcwd()
n_capitals = 117  # number of capitals
n_timepoints = 31  # days

uniq_capital = concat26['capital'].unique()
month_years = concat26['month_year'].unique()
n_samples = len(month_years)

## sort by capital name
concat26 = concat26.sort_values(by=['dmy','capital']).copy()

# Pre-allocate arrays
temp_matrices = np.zeros((n_samples, n_capitals, n_timepoints), dtype=np.float32)
masks = np.zeros((n_samples, n_capitals, n_timepoints), dtype=np.float32)
month_year_list = []

for idx, my in enumerate(month_years):
    print(f"Processing: {my}")

    try:
        # Get data for this month/year
        month_data = concat26[concat26['month_year'] == my]

        for i, capital in enumerate(uniq_capital):
            capital_data = month_data[month_data['capital'] == capital].sort_values('dmy')
            temp_values = capital_data['avg_temp_c'].values

            if len(temp_values) > 0:
                temp_matrices[idx, i, :len(temp_values)] = temp_values
                masks[idx, i, :len(temp_values)] = 1.0


        month_year_list.append(my)
    except Exception as e:
        print(f"Couldnt process: {my}")
# Out:
# Processing: 2026-01
# Processing: 2026-02

# %%
# Save to npz file
np.savez_compressed(
    'data_/openmeteo-janfev26.npz',
    temp_matrices=temp_matrices,  # shape: (n_samples, n_capitals, n_timepoints)
    masks=masks,                  # shape: (n_samples, n_capitals, n_timepoints)
    month_years=np.array(month_year_list),  # shape: (n_samples,)
    capitals=uniq_capital         # shape: (n_capitals,)
)
