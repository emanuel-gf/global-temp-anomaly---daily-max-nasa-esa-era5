# %%
import openmeteo_requests
import requests_cache
import pandas as pd
from retry_requests import retry
from datetime import date

# %%
## generate a random dataset in pandas and save it as a paruqet
df = pd.DataFrame({
    'lat': [51.4700, 51.4700, 51.4700],
    'lon': [-0.4543, -0.4543, -0.4543],
})
df.to_parquet('testj.parquet')

# %%
def fetch_weather_data(openmeteo, params: dict):
        """
        Fetches ECMWF IFS for the given parameters.
        It looks for a single point, which is also passed inside the params dict

        Args:
            openmeteo = Object API
            params: dict 
                Dict of the API parameters.
        """
        
        url = "https://archive-api.open-meteo.com/v1/archive"

        # API call returns a list of responses (one per location)
        responses = openmeteo.weather_api(url, params=params)

        return response

# %%
# Indefinite caching is recommended for historical data to avoid re-requesting the same years
cache_session = requests_cache.CachedSession('.cache', expire_after=-1)
retry_session = retry(cache_session, retries=5, backoff_factor=0.2)
openmeteo = openmeteo_requests.Client(session=retry_session)
